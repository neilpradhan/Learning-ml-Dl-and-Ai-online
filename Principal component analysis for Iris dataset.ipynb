# %% [markdown]
# # Here is the pca analysis for a 4 feature Iris dataset reduced to 2 dimensions.
# referrence : (https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60)

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# load dataset into Pandas DataFrame
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])
df.head(5)
# Out:
#    sepal length  sepal width  petal length  petal width       target
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Pca is a dimentionality reduction technique. Here we have 4 dimensions which we plan to reduce to 3 or 2 dimensions.

# %%
from sklearn.preprocessing import StandardScaler
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
# Separating out the features
x = df.loc[:, features].values
print(x[0:3])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]]

# %%
# Separating out the target
y = df.loc[:,['target']].values
print(y[0:3])
# Out:
# [['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']]

# %%
x = StandardScaler().fit_transform(x)
print(x[0:3])
# Out:
# [[-0.90068117  1.03205722 -1.3412724  -1.31297673]
#  [-1.14301691 -0.1249576  -1.3412724  -1.31297673]
#  [-1.38535265  0.33784833 -1.39813811 -1.31297673]]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
print(principalComponents[0:3])
# Out:
# [[-2.26454173  0.5057039 ]
#  [-2.0864255  -0.65540473]
#  [-2.36795045 -0.31847731]]

# %%
principalDF =pd.DataFrame(data = principalComponents, columns = ['pc 1', 'pc 2'])
principalDF.head(4)
# Out:
#        pc 1      pc 2
# 0 -2.264542  0.505704
# 1 -2.086426 -0.655405
# 2 -2.367950 -0.318477
# 3 -2.304197 -0.575368

# %%
df['target'].head(4)
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# Name: target, dtype: object

# %%
finalDf = pd.concat([principalDF, df[['target']]], axis = 1)
finalDf
# Out:
#          pc 1      pc 2          target
# 0   -2.264542  0.505704     Iris-setosa
# 1   -2.086426 -0.655405     Iris-setosa
# 2   -2.367950 -0.318477     Iris-setosa
# 3   -2.304197 -0.575368     Iris-setosa
# 4   -2.388777  0.674767     Iris-setosa
# 5   -2.070537  1.518549     Iris-setosa
# 6   -2.445711  0.074563     Iris-setosa
# 7   -2.233842  0.247614     Iris-setosa
# 8   -2.341958 -1.095146     Iris-setosa
# 9   -2.188676 -0.448629     Iris-setosa
# 10  -2.163487  1.070596     Iris-setosa
# 11  -2.327378  0.158587     Iris-setosa
# 12  -2.224083 -0.709118     Iris-setosa
# 13  -2.639716 -0.938282     Iris-setosa
# 14  -2.192292  1.889979     Iris-setosa
# 15  -2.251465  2.722371     Iris-setosa
# 16  -2.202750  1.513750     Iris-setosa
# 17  -2.190179  0.514304     Iris-setosa
# 18  -1.894074  1.431111     Iris-setosa
# 19  -2.339949  1.158033     Iris-setosa
# 20  -1.914556  0.430465     Iris-setosa
# 21  -2.204645  0.952457     Iris-setosa
# ...

# %% [markdown]
# # Visualize 2D Projection

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (10,8))
ax =fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'pc 1']
               , finalDf.loc[indicesToKeep, 'pc 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()


plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.72770452, 0.23030523])

# %% [markdown]
# As we loose variance when we do the operation of dimension reduction,  we notice that for the 1st pca we have retained 72% info and likewise for the 2nd pc we have 23% and together we have retained almost 95% info thus believing our pca analysis.

# %% [markdown]
# For more information on interpretation of pca analysis we can go on
# https://support.minitab.com/en-us/minitab/18/help-and-how-to/modeling-statistics/multivariate/how-to/principal-components/interpret-the-results/key-results/
